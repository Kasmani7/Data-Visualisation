# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x, y, 'mo--', linewidth=2, markersize=12)

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x, y, color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12)

# %%
def create_random_walk():
    x = np.random.choice([1,-9],size=100, replace=True) # Sample with replacement from (-1, 1)
    return np.cumsum(x)

X = create_random_walk()
Y = create_random_walk()
Z = create_random_walk()

# Plotting functionality starts here
plt.plot(X)
plt.plot(Y)
plt.plot(Z)

plt.plot(X, '-.', color="#333333")
plt.plot(Y, '-.', color="chocolate")
plt.plot(Z, '-.', color="green")
plt.show()

# %%
x = np.linspace(0, 6, 100)
y_1 = 5*x
y_2 = np.power(x, 2)
y_3 = np.exp(x/1.5)
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.plot(x, y_1, '-.', color="red")
plt.plot(x, y_2, '--', color="green")
plt.plot(x, y_3, '-', color="cyan")

plt.show()

# %% [markdown]
# # Control Color

# %%
y = np.arange(1, 3)
plt.plot(y, 'y');
plt.plot(y+1, 'm');
plt.plot(y+2, 'c');
plt.show()

# %%
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
y = np.arange(1, 3, 0.2)
plt.plot(y, 'x', y+0.5, 'o', y+1, 'D', y+1.5, '^', y+2, 's');
plt.show()

# %%
x = [5, 3, 7, 2, 4, 1]
plt.plot(x)
plt.xticks(range(len(x)), ['a', 'b', 'c', 'd', 'e', 'f'])
plt.yticks(range(1, 8))
plt.show()

# %%
y = np.random.randn(1000) 
plt.hist(y)
plt.show()

# %%
plt.hist(y,7)
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=10, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
objects = ('Python', 'Java Script', 'R', 'Ruby', 'Scala', 'Java')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
objects = ('Python', 'Java Script', 'R', 'Ruby', 'Scala', 'Java')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
x = [1, 2, 3, 4]

y = [1, 4, 9, 16]
e = [0.5, 1., 1.5, 2.]
plt.errorbar(x, y, yerr=e, fmt='b')
plt.show()

# %%
plt.figure(figsize=(3,3));
x = [45, 35, 20]
labels = ['Cats', 'Dogs', 'Fishes']
plt.pie(x, labels=labels);
plt.show()

# %%
plt.figure(figsize=(3,3))
x = [4, 9, 21, 55, 30, 18]
labels = ['Swiss', 'Austria', 'Spain', 'Italy', 'France','Benelux']
explode = [0.2, 0.1, 0, 0, 0.1, 0]
plt.pie(x, labels=labels)
plt.show()

# %%
plt.figure(figsize=(3,8))
x = [4, 9, 21, 55, 30, 18]
labels = ['Swiss', 'Austria', 'Spain', 'Italy', 'France','Benelux']
explode = [0.2, 0.1, 0, 0, 0.1, 0]
plt.pie(x, labels=labels , explode = explode)
plt.show()

# %%
plt.figure(figsize=(3,3))
x = [4, 9, 21, 55, 30, 18]
labels = ['Swiss', 'Austria', 'Spain', 'Italy', 'France','Benelux']
explode = [0.2, 0.1, 0, 0, 0.1, 0]
plt.pie(x, labels=labels , explode = explode , autopct='%5.1f%%' )
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y);
plt.show()

# %%
size = 50*np.random.randn(1000)
colors = np.random.rand(1000)
plt.scatter(x, y, s=size, c=colors)
plt.show()

# %%
y = [13, 11, 13, 12, 13, 10, 30, 12, 11, 13, 12, 12, 12, 11,12]
plt.plot(y)
plt.ylim(ymax=38)
plt.annotate('this spot must really\nmean something',  
             xy=(6, 30), xytext=(8, 31.5), arrowprops=dict(facecolor='black',shrink=0.05))
plt.show()
