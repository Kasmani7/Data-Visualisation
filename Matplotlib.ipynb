# %%
a = 2019
b = sum(list(map(int,str(a))))
b
# Out:
# 12

# %% [markdown]
# # DATA VISUALISATION

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(5,5,'o')

# %%
plt.plot([1,3,2,4,7])

# %%
plt.plot([i**2 for i in range(6)])

# %%
import numpy as np

# %%
plt.plot(np.random.randn(50).cumsum())
plt.show()

# %%
plt.plot([x**3 for x in np.arange(0,10,2)])

# %% [markdown]
# # MULTILINE Graph

# %%
x = np.arange(0,8)
plt.plot([i**2 for i in x],'r' , [i*3 for i in x],'c',[i*4 for i in x])
# Out:
# [<matplotlib.lines.Line2D at 0x1e5bac380c8>,
#  <matplotlib.lines.Line2D at 0x1e5bac3af48>,
#  <matplotlib.lines.Line2D at 0x1e5bac43148>]

# %%
a = np.arange(8)
plt.plot(a,a**1.5,a**2,a/2)
# Out:
# [<matplotlib.lines.Line2D at 0x1e5baca4cc8>,
#  <matplotlib.lines.Line2D at 0x1e5bacadb48>]

# %% [markdown]
# # ADDING A GRID

# %%
x = np.arange(5)
plt.plot(x,x*1.5,x*1.75,x*2, x/4, x/1.55)
plt.grid(True)

# %%
plt.plot(5,9,'o')
plt.xlabel('X Points')
plt.ylabel('Y Points')
plt.title('Practice Graph')
# Out:
# Text(0.5, 1.0, 'Practice Graph')

# %%
import pandas as pd

# %%
pd = pd.DataFrame({'Age':[35,40,22,25,50] , 'Weight':[90,87,50,35,100]})
pd
# Out:
#    Age  Weight
# 0   35      90
# 1   40      87
# 2   22      50
# 3   25      35
# 4   50     100

# %%
pd.plot(kind = 'line')

# %%
plt.plot(pd['Age'],pd['Weight'],'ro')          #ro:red dots

# %%
def walk():
    x = np.random.randn(50)
    return np.cumsum(x)

X = walk()
Y = walk()
Z = walk()

# %%
plt.plot(X , label='X')
plt.plot(Y, label='Y')
plt.plot(Z, label='Z')
plt.legend(loc = 'lower left')

# %%
plt.plot(X,Y,Z)                        #first plot x and y and z is plotted as independent
plt.title('Random Walk')
plt.suptitle('GRAPH' , fontsize = 16 , fontweight ='bold')
# Out:
# Text(0.5, 0.98, 'GRAPH')

# %% [markdown]
# # DESIGNING

# %%
plt.plot([1,3,6,7] , [2,4,8,10] , 'ro')           #1,2 - 3,4 - 6,8 - 7,10   
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot([1,3,6,7] , [2,4,8,10] , 'r+')           #1,2 - 3,4 - 6,8 - 7,10   
#plt.axis([])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot([1,3,6,7] , [2,4,8,10] , 'go--')           #1,2 - 3,4 - 6,8 - 7,10   
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
w = [1,2,3,4,5]
u = [1,4,9,16,25]
plt.plot(w,u,'yo',linewidth=2,linestyle='dotted',markersize=12)

# %%
import numpy as np
def create_random_walk():
    x = np.random.choice([-1,1],size=100, replace=True) # Sample with replacement from (-1, 1)
    return np.cumsum(x)

X = create_random_walk()
Y = create_random_walk()
Z = create_random_walk()

# Plotting functionality starts here
plt.plot(X)
plt.plot(Y)
plt.plot(Z)

plt.plot(X, '-.', color="#333333")
plt.plot(Y, '-.', color="chocolate")
plt.plot(Z, '-.', color="green")
plt.show()

# %%
x = np.linspace(0, 6, 100)
y_1 = 5*x
y_2 = np.power(x, 2)
y_3 = np.exp(x/1.5)
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.plot(x, y_1, '-.', color="#333333")
plt.plot(x, y_2, '--', color="#999999")
plt.plot(x, y_3, '-', color="#aaaaaa")

plt.show()

# %% [markdown]
# # Control Colors

# %%
y = np.arange(1, 3)
plt.plot(y, 'y');
plt.plot(y+1, 'm');
plt.plot(y+2, 'c');
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
y = np.arange(1, 3, 0.2)
plt.plot(y, 'x', y+0.5, 'o', y+1, 'D', y+1.5, '^', y+2, 's');
plt.show()

# %%
x = [5, 3, 7, 2, 4, 1]
plt.plot(x)
plt.xticks(range(len(x)), ['a', 'b', 'c', 'd', 'e', 'f'])
plt.yticks(range(1, 8, 2))
plt.show()

# %% [markdown]
# # Histogram charts

# %%
y = np.random.randn(1000) 
plt.hist(y)
plt.show()

# %%
plt.hist(y,25)
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
objects = ('Python', 'Java Script', 'R', 'Ruby', 'Scala', 'Java')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')

plt.show()

# %%
objects = ('Python', 'R', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.barh(y_pos, performance, align='center', alpha=1)      #bar h se horizontal bar banenge
plt.yticks(y_pos, objects)
plt.xlabel('Usage')
plt.title('Programming language usage')

plt.show()
